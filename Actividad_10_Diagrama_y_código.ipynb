# %% [markdown]
# <a href="https://colab.research.google.com/github/medinazubiaana-byte/diagrama-gael/blob/main/Actividad_10_Diagrama_y_c%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Anais Medina

# %%
# genera una diagramade flujo para un sistema de transporte de tu ciudad. el programa te pedira tu edad, si eres menor de 12 o mayor de 60 años, pagaras una tarifa profidencial de 5 pesos.
# si tu edad no esta en ninguno rango, paragas el coste normal de 12 pesos

edad = float(input("Ingresa tu edad: "))
if edad <= 12:
  print("pagaras solo 5 pesos")
elif edad >= 60:
  print("pagaras solo 5 pesos")
else:
  print("Pagaras 12 pesos")
# Out:
# Ingresa tu edad: 70
# pagaras solo 5 pesos

# %%
# genera una diagramade flujo para un sistema de transporte de tu ciudad. el programa te pedira tu edad, si eres menor de 12 o mayor de 60 años, pagaras una tarifa profidencial de 5 pesos.
# si tu edad no esta en ninguno rango, paragas el coste normal de 12 pesos

edad = float(input("Ingresa tu edad: "))
if edad <= 12:
  print("pagaras solo 5 pesos")
if edad >= 60:
 print("pagaras solo 5 pesos")
if edad >=13:
  print("Pagaras 12 pesos")
# Out:
# Ingresa tu edad: 5
# pagaras solo 5 pesos

# %%
# genera una diagramade flujo para un sistema de transporte de tu ciudad. el programa te pedira tu edad, si eres menor de 12 o mayor de 60 años, pagaras una tarifa profidencial de 5 pesos.
# si tu edad no esta en ninguno rango, paragas el coste normal de 12 pesos

edad = float(input("Ingresa tu edad: "))
if edad <= 12:
  print("pagaras solo 5 pesos")
if edad >= 60:
 print("pagaras solo 5 pesos")
if edad >=13:
  print("Pagaras 12 pesos")
# Out:
# Ingresa tu edad: 56
# Pagaras 12 pesos
